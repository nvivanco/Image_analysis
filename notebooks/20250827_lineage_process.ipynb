# %%
import os
import cell_lineage_tracking as lineage
import gnn_ben_haim as bh_track
import tifffile
import matplotlib.pyplot as plt
from skimage.measure import find_contours
from skimage.draw import polygon
from matplotlib.collections import LineCollection
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import torch
torch.set_default_dtype(torch.float32)
from torch_geometric.loader import DataLoader
from torch_geometric.transforms import BaseTransform
import torch.nn as nn
from torch.utils.data import Subset
import lineage_detection

# %%
strain_exp_dict = {# need araB gitg61/CL08 lineage tracing CL008_giTG068_072925 pos 0-10 is CL08 # don't see fluor signal
                  # need alkA gitg63 lineage tracing potentially DUMM_giTG63_giTG67_Glucose_121724_1 pos 5, 'DUMM_giTG068_063_061725' look at pos 1-8, had pos 0 but bad for lineage
                  # need murQ gitg67 lineage tracing potenitally DUMM_giTG068_067_061825 or DUMM_giTG63_giTG67_Glucose_121724_1 pos 6-9

                  'chpS': ['DUMM_giTG62_Glucose_012925'],  #need lineage tracing, Nora working on it
                  'baeS':['DUMM_giTG66_Glucose_012325'],  # need to find new exp, lineage tracing is bad on this one
                  'lacZ':['DUMM_giTG059_noKan_Glucose_031125'],
                  'gfcE': ['DUMM_giTG064_Glucose_022625'],
                  'gldA': ['DUMM_giTG69_Glucose_013025'],
                  #'murQ': [' DUMM_giTG63_giTG67_Glucose_121724_1'],
                  'alkA': ['DUMM_giTG068_063_061725_v2','DUMM_giTG63_giTG67_Glucose_121724_1_v2'],
                  'mazF': ['DUMM_giTG059_060_061125'], # constitutive
                  'hupA':['DUMM_giTG068_052925', 'DUMM_giTG068_063_061725'] # constitutive
                  }

# %%
df_all = pd.DataFrame()
for gene, exps in strain_exp_dict.items():
    for exp_view in exps:
        print(exp_view)
        all_cells_filename = f'/Users/noravivancogonzalez/Documents/DuMM_image_analysis/all_cell_data_{exp_view}.pkl'
        all_cells_pd = pd.read_pickle(all_cells_filename)
        all_cells_pd['gene'] = gene
        if df_all.empty:
            df_all = all_cells_pd
        else:
            df_all = pd.concat([df_all, all_cells_pd], ignore_index=True)
# Out:
# DUMM_giTG62_Glucose_012925
# DUMM_giTG66_Glucose_012325
# DUMM_giTG059_noKan_Glucose_031125
# DUMM_giTG064_Glucose_022625
# DUMM_giTG69_Glucose_013025
# DUMM_giTG068_063_061725_v2
# DUMM_giTG63_giTG67_Glucose_121724_1_v2
# DUMM_giTG059_060_061125
# DUMM_giTG068_052925
# DUMM_giTG068_063_061725

# %%
df_all['node_id'] = df_all.index

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

# %%
node_feature_cols = ['area', 'centroid_y', 
       'axis_major_length', 'axis_minor_length', 'intensity_mean_phase',
       'intensity_max_phase', 'intensity_min_phase', 'intensity_mean_fluor',
       'intensity_max_fluor', 'intensity_min_fluor']
for col in node_feature_cols:
    df_all[col] = df_all[col].astype(np.float32);

# %%
# Access the node features from the single train_df DataFrame.
all_train_node_features_df = df_all[node_feature_cols].values.astype(np.float32)

# Initialize and fit the scaler on the training data.
scaler = StandardScaler()
scaler.fit(all_train_node_features_df)
print("Scaler fitted on training data.")

# Create an instance of the transform with the fitted scaler.
transform = bh_track.StandardScalerTransform(scaler)

dataset = bh_track.CellTrackingDataset(root='./processed_data_bh/full_dataset',
                                   df_cells=df_all,
                                   node_feature_cols=node_feature_cols,
                                   device=device,
                                   pre_transform=transform)

batch_size = 32
test_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

print(f"Number of test graphs: {len(dataset)}")
# Out:
# Scaler fitted on training data.
# Starting data processing for processed_data_bh/full_dataset...
# Processing...
# Finished processing. Created 50 PyG Data objects.
# Processed data saved to processed_data_bh/full_dataset/processed/cell_tracking_fovs.pt
# Number of test graphs: 1
# Done!

# %%
num_node_features = len(node_feature_cols)
initial_edge_feature_dim = len(node_feature_cols) + 1
hidden_channels = 128 # balance between expressiveness and compute

model = bh_track.LineageLinkPredictionGNN(in_channels=num_node_features,
    initial_edge_channels=initial_edge_feature_dim, 
    hidden_channels=128,
    num_blocks=2).to(device)
model.load_state_dict(torch.load('best_link_prediction_model.pt'))
print("Loaded best model cell linkage.")

lineage_predictions_df = bh_track.predict_cell_linkages(model,
                                                       test_loader,
                                                       device)
# Out:
# Loaded best model cell linkage.

# %%
df_consolidated_lineages =  lineage_detection.process_all_fovs(lineage_predictions_df, df_all, prob_threshold=0.8)
# Out:
# Column 'ground_truth_lineage' found. Including it in node attributes.
# --- Processing FOV 1/50: DUMM_giTG62_Glucose_012925, 005, 445 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 390 nodes and 304 edges.
#
# All cycles have been removed.
# Final graph has 390 nodes and 304 edges.
# Successfully generated 304 lineage rows.
# --- Processing FOV 2/50: DUMM_giTG62_Glucose_012925, 005, 900 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 109 nodes and 96 edges.
#
# All cycles have been removed.
# Final graph has 109 nodes and 96 edges.
# Successfully generated 96 lineage rows.
# --- Processing FOV 3/50: DUMM_giTG62_Glucose_012925, 005, 1128 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 269 nodes and 215 edges.
#
# All cycles have been removed.
# Final graph has 269 nodes and 215 edges.
# Successfully generated 215 lineage rows.
# --- Processing FOV 4/50: DUMM_giTG62_Glucose_012925, 005, 1277 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 414 nodes and 311 edges.
#
# All cycles have been removed.
# Final graph has 414 nodes and 311 edges.
# Successfully generated 311 lineage rows.
# --- Processing FOV 5/50: DUMM_giTG62_Glucose_012925, 005, 1887 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 565 nodes and 440 edges.
#
# All cycles have been removed.
# Final graph has 565 nodes and 440 edges.
# Successfully generated 440 lineage rows.
# --- Processing FOV 6/50: DUMM_giTG62_Glucose_012925, 005, 2115 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 245 nodes and 183 edges.
#
# All cycles have been removed.
# Final graph has 245 nodes and 183 edges.
# Successfully generated 183 lineage rows.
# --- Processing FOV 7/50: DUMM_giTG62_Glucose_012925, 005, 2344 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 556 nodes and 393 edges.
#
# All cycles have been removed.
# Final graph has 556 nodes and 393 edges.
# Successfully generated 393 lineage rows.
# --- Processing FOV 8/50: DUMM_giTG62_Glucose_012925, 005, 2421 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 645 nodes and 470 edges.
#
# All cycles have been removed.
# Final graph has 645 nodes and 470 edges.
# Successfully generated 470 lineage rows.
# --- Processing FOV 9/50: DUMM_giTG62_Glucose_012925, 005, 2497 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 491 nodes and 345 edges.
#
# All cycles have been removed.
# Final graph has 491 nodes and 345 edges.
# Successfully generated 345 lineage rows.
# --- Processing FOV 10/50: DUMM_giTG66_Glucose_012325, 003, 250 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 371 nodes and 608 edges.
#
# All cycles have been removed.
# Final graph has 371 nodes and 608 edges.
# Successfully generated 608 lineage rows.
# --- Processing FOV 11/50: DUMM_giTG66_Glucose_012325, 003, 275 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 216 nodes and 369 edges.
#
# All cycles have been removed.
# Final graph has 216 nodes and 369 edges.
# Successfully generated 369 lineage rows.
# --- Processing FOV 12/50: DUMM_giTG66_Glucose_012325, 003, 453 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 119 nodes and 109 edges.
#
# All cycles have been removed.
# Final graph has 119 nodes and 109 edges.
# Successfully generated 109 lineage rows.
# --- Processing FOV 13/50: DUMM_giTG66_Glucose_012325, 003, 479 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 158 nodes and 161 edges.
#
# All cycles have been removed.
# Final graph has 158 nodes and 161 edges.
# Successfully generated 161 lineage rows.
# --- Processing FOV 14/50: DUMM_giTG059_noKan_Glucose_031125, 004, 756 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 475 nodes and 388 edges.
#
# All cycles have been removed.
# Final graph has 475 nodes and 388 edges.
# Successfully generated 388 lineage rows.
# --- Processing FOV 15/50: DUMM_giTG059_noKan_Glucose_031125, 004, 832 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 594 nodes and 449 edges.
#
# All cycles have been removed.
# Final graph has 594 nodes and 449 edges.
# Successfully generated 449 lineage rows.
# --- Processing FOV 16/50: DUMM_giTG059_noKan_Glucose_031125, 004, 72 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 369 nodes and 315 edges.
#
# All cycles have been removed.
# Final graph has 369 nodes and 315 edges.
# Successfully generated 315 lineage rows.
# --- Processing FOV 17/50: DUMM_giTG059_noKan_Glucose_031125, 004, 1820 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 841 nodes and 736 edges.
#
# All cycles have been removed.
# Final graph has 841 nodes and 736 edges.
# Successfully generated 736 lineage rows.
# --- Processing FOV 18/50: DUMM_giTG059_noKan_Glucose_031125, 004, 985 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 248 nodes and 196 edges.
#
# All cycles have been removed.
# Final graph has 248 nodes and 196 edges.
# Successfully generated 196 lineage rows.
# --- Processing FOV 19/50: DUMM_giTG059_noKan_Glucose_031125, 004, 1061 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 242 nodes and 217 edges.
#
# All cycles have been removed.
# Final graph has 242 nodes and 217 edges.
# Successfully generated 217 lineage rows.
# --- Processing FOV 20/50: DUMM_giTG059_noKan_Glucose_031125, 004, 2276 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 264 nodes and 293 edges.
#
# All cycles have been removed.
# Final graph has 264 nodes and 293 edges.
# Successfully generated 293 lineage rows.
# --- Processing FOV 21/50: DUMM_giTG064_Glucose_022625, 001, 114 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 532 nodes and 484 edges.
#
# All cycles have been removed.
# Final graph has 532 nodes and 484 edges.
# Successfully generated 484 lineage rows.
# --- Processing FOV 22/50: DUMM_giTG064_Glucose_022625, 001, 189 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 309 nodes and 242 edges.
#
# All cycles have been removed.
# Final graph has 309 nodes and 242 edges.
# Successfully generated 242 lineage rows.
# --- Processing FOV 23/50: DUMM_giTG064_Glucose_022625, 001, 415 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 629 nodes and 544 edges.
#
# All cycles have been removed.
# Final graph has 629 nodes and 544 edges.
# Successfully generated 544 lineage rows.
# --- Processing FOV 24/50: DUMM_giTG064_Glucose_022625, 001, 867 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 526 nodes and 444 edges.
#
# All cycles have been removed.
# Final graph has 526 nodes and 444 edges.
# Successfully generated 444 lineage rows.
# --- Processing FOV 25/50: DUMM_giTG064_Glucose_022625, 001, 943 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 757 nodes and 668 edges.
#
# All cycles have been removed.
# Final graph has 757 nodes and 668 edges.
# Successfully generated 668 lineage rows.
# --- Processing FOV 26/50: DUMM_giTG064_Glucose_022625, 001, 1697 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 493 nodes and 462 edges.
#
# All cycles have been removed.
# Final graph has 493 nodes and 462 edges.
# Successfully generated 462 lineage rows.
# --- Processing FOV 27/50: DUMM_giTG064_Glucose_022625, 001, 2376 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 483 nodes and 441 edges.
#
# All cycles have been removed.
# Final graph has 483 nodes and 441 edges.
# Successfully generated 441 lineage rows.
# --- Processing FOV 28/50: DUMM_giTG064_Glucose_022625, 015, 796 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 993 nodes and 808 edges.
#
# All cycles have been removed.
# Final graph has 993 nodes and 808 edges.
# Successfully generated 808 lineage rows.
# --- Processing FOV 29/50: DUMM_giTG69_Glucose_013025, 007, 295 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 415 nodes and 329 edges.
#
# All cycles have been removed.
# Final graph has 415 nodes and 329 edges.
# Successfully generated 329 lineage rows.
# --- Processing FOV 30/50: DUMM_giTG69_Glucose_013025, 007, 371 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 468 nodes and 367 edges.
#
# All cycles have been removed.
# Final graph has 468 nodes and 367 edges.
# Successfully generated 367 lineage rows.
# --- Processing FOV 31/50: DUMM_giTG69_Glucose_013025, 007, 521 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 356 nodes and 271 edges.
#
# All cycles have been removed.
# Final graph has 356 nodes and 271 edges.
# Successfully generated 271 lineage rows.
# --- Processing FOV 32/50: DUMM_giTG69_Glucose_013025, 007, 597 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 454 nodes and 362 edges.
#
# All cycles have been removed.
# Final graph has 454 nodes and 362 edges.
# Successfully generated 362 lineage rows.
# --- Processing FOV 33/50: DUMM_giTG69_Glucose_013025, 007, 1124 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 539 nodes and 410 edges.
#
# All cycles have been removed.
# Final graph has 539 nodes and 410 edges.
# Successfully generated 410 lineage rows.
# --- Processing FOV 34/50: DUMM_giTG068_063_061725_v2, 006, 1292 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 156 nodes and 134 edges.
#
# All cycles have been removed.
# Final graph has 156 nodes and 134 edges.
# Successfully generated 134 lineage rows.
# --- Processing FOV 35/50: DUMM_giTG068_063_061725_v2, 006, 1368 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 398 nodes and 323 edges.
#
# All cycles have been removed.
# Final graph has 398 nodes and 323 edges.
# Successfully generated 323 lineage rows.
# --- Processing FOV 36/50: DUMM_giTG068_063_061725_v2, 006, 1596 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 130 nodes and 99 edges.
#
# All cycles have been removed.
# Final graph has 130 nodes and 99 edges.
# Successfully generated 99 lineage rows.
# --- Processing FOV 37/50: DUMM_giTG63_giTG67_Glucose_121724_1_v2, 005, 296 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 917 nodes and 789 edges.
#
# All cycles have been removed.
# Final graph has 917 nodes and 789 edges.
# Successfully generated 789 lineage rows.
# --- Processing FOV 38/50: DUMM_giTG63_giTG67_Glucose_121724_1_v2, 005, 756 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 191 nodes and 158 edges.
#
# All cycles have been removed.
# Final graph has 191 nodes and 158 edges.
# Successfully generated 158 lineage rows.
# --- Processing FOV 39/50: DUMM_giTG63_giTG67_Glucose_121724_1_v2, 005, 1217 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 182 nodes and 135 edges.
#
# All cycles have been removed.
# Final graph has 182 nodes and 135 edges.
# Successfully generated 135 lineage rows.
# --- Processing FOV 40/50: DUMM_giTG63_giTG67_Glucose_121724_1_v2, 005, 2210 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 156 nodes and 104 edges.
#
# All cycles have been removed.
# Final graph has 156 nodes and 104 edges.
# Successfully generated 104 lineage rows.
# --- Processing FOV 41/50: DUMM_giTG059_060_061125, 008, 431 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 179 nodes and 122 edges.
#
# All cycles have been removed.
# Final graph has 179 nodes and 122 edges.
# Successfully generated 122 lineage rows.
# --- Processing FOV 42/50: DUMM_giTG059_060_061125, 008, 1488 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 226 nodes and 151 edges.
#
# All cycles have been removed.
# Final graph has 226 nodes and 151 edges.
# Successfully generated 151 lineage rows.
# --- Processing FOV 43/50: DUMM_giTG059_060_061125, 015, 1826 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 200 nodes and 142 edges.
#
# All cycles have been removed.
# Final graph has 200 nodes and 142 edges.
# Successfully generated 142 lineage rows.
# --- Processing FOV 44/50: DUMM_giTG068_052925, 005, 387 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 305 nodes and 269 edges.
#
# All cycles have been removed.
# Final graph has 305 nodes and 269 edges.
# Successfully generated 269 lineage rows.
# --- Processing FOV 45/50: DUMM_giTG068_052925, 005, 539 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 522 nodes and 447 edges.
#
# All cycles have been removed.
# Final graph has 522 nodes and 447 edges.
# Successfully generated 447 lineage rows.
# --- Processing FOV 46/50: DUMM_giTG068_052925, 005, 1906 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 601 nodes and 478 edges.
#
# All cycles have been removed.
# Final graph has 601 nodes and 478 edges.
# Successfully generated 478 lineage rows.
# --- Processing FOV 47/50: DUMM_giTG068_052925, 005, 843 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 149 nodes and 125 edges.
#
# All cycles have been removed.
# Final graph has 149 nodes and 125 edges.
# Successfully generated 125 lineage rows.
# --- Processing FOV 48/50: DUMM_giTG068_052925, 005, 2209 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 134 nodes and 116 edges.
#
# All cycles have been removed.
# Final graph has 134 nodes and 116 edges.
# Successfully generated 116 lineage rows.
# --- Processing FOV 49/50: DUMM_giTG068_063_061725, 000, 1750 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 379 nodes and 337 edges.
#
# All cycles have been removed.
# Final graph has 379 nodes and 337 edges.
# Successfully generated 337 lineage rows.
# --- Processing FOV 50/50: DUMM_giTG068_063_061725, 012, 1565 ---
# --- Adding nodes with all experimental data... ---
# --- Building initial graph with edges... ---
# Initial graph has 374 nodes and 322 edges.
#
# All cycles have been removed.
# Final graph has 374 nodes and 322 edges.
# Successfully generated 322 lineage rows.

# %%
df_for_kymograph_plot = lineage_detection.consolidate_lineages_to_node_df(df_consolidated_lineages, df_all)
# Out:
# --- Consolidating lineage data to a node-centric format... ---
# --- Consolidation complete. Final DataFrame is ready for plotting. ---

# %%
tracked_all_cells_filename = f'/Users/noravivancogonzalez/Documents/DuMM_image_analysis/20250829_tracked_all_cell_data.pkl'
df_for_kymograph_plot.to_pickle(tracked_all_cells_filename)

# %%
tracked_all_cells_filename = f'/Users/noravivancogonzalez/Documents/DuMM_image_analysis/20250829_tracked_all_cell_data.pkl'
df_for_kymograph_plot = pd.read_pickle(tracked_all_cells_filename)

# %%
df_for_kymograph_plot.head(5)
# Out:
#    label   area                                             coords  \
# 0      1  182.0  [[0, 166], [0, 167], [0, 168], [0, 169], [0, 1...
# 1      3  233.0  [[0, 226], [0, 227], [0, 228], [0, 229], [0, 2...
# 2      5  165.0  [[0, 325], [0, 326], [0, 327], [0, 328], [0, 3...
# 3      7  198.0  [[0, 2087], [0, 2088], [0, 2089], [1, 2087], [...
# 4     11  223.0  [[0, 2203], [0, 2204], [0, 2205], [0, 2206], [...
#
#    centroid_y   centroid_x  axis_major_length  axis_minor_length  \
# 0   14.615385   169.423077          37.096642           6.667422
# 1   16.566525   230.412017          42.404186           7.669648
# 2   10.478787   328.666667          26.321367           8.304471
# 3   16.934343  2086.919192          38.740509           6.952181
# 4   16.847534  2207.161435          41.267384           7.352654
#
#    intensity_mean_phase  intensity_max_phase  intensity_min_phase  ...  \
# 0           8683.736328              11092.0               6837.0  ...
# 1           8531.793945              10206.0               6804.0  ...
# 2           8684.884766              11109.0               6299.0  ...
# 3           8277.232422              10729.0               6501.0  ...
# 4           8576.610352              11085.0               6741.0  ...
#
#    intensity_min_fluor  time_frame             experiment_name  FOV trench_id  \
# 0                  6.0         8.0  DUMM_giTG62_Glucose_012925  005       445
# 1                  0.0        11.0  DUMM_giTG62_Glucose_012925  005       445
# 2                  0.0        16.0  DUMM_giTG62_Glucose_012925  005       445
# 3                  0.0       104.0  DUMM_giTG62_Glucose_012925  005       445
# 4                  0.0       110.0  DUMM_giTG62_Glucose_012925  005       445
#
#   track_id node_id ground_truth_lineage  gene predicted_lineage
# 0       19       0                  NaN  chpS                 5
# 1       30       2                  NaN  chpS                11
# 2       49       4                  NaN  chpS               4.1
# 3      123       6                  NaN  chpS                 6
# 4      141      10                  NaN  chpS                 9
#
# [5 rows x 22 columns]

# %%
def plot_kymograph_cells_id(phase_kymograph, fluor_kymograph, full_region_df, folder, fov_id, peak_id, track_id_col='track_id'):
    fig, ax = plt.subplots(1,1, figsize=(40, 10))

    # Get kymograph shape once for both calls
    kymograph_shape = phase_kymograph.shape

    ax.imshow(phase_kymograph, cmap = 'grey')
    _plot_cell_masks(ax, full_region_df, kymograph_shape, y_coord_col = 'centroid_y', x_coord_col = 'centroid_x', lineage_col = track_id_col)
    ax.set_yticks([])
    ax.set_xticks([])
    ax.set_title(f'Phase Kymograph - {folder} FOV: {fov_id}, trench: {peak_id}')

    plt.xlabel("Time frames")
    plt.tight_layout()

    plt.savefig(f'{folder}_FOV_{fov_id}_trench_{peak_id}_kymograph.png', dpi=300, bbox_inches='tight')
    plt.close(fig)

def _plot_cell_masks(ax, full_region_df, kymograph_shape, y_coord_col = 'centroid_y', x_coord_col = 'centroid_x', lineage_col = None):
    default_cell_contour_color = '#AA5486'
    default_centroid_color = '#FC8F54'
    text_color = 'white' # Color for the track ID text
    text_offset_x = 5 # Offset the text slightly from the centroid to avoid overlap
    text_offset_y = 0

    # Prepare data for LineCollection for contours
    all_contours_segments = []
    all_contour_colors = []
    
    # Prepare data for centroids
    centroid_x_coords = []
    centroid_y_coords = []
    centroid_colors = []

    all_text_params = []

    if lineage_col:
        unique_track_ids = full_region_df[lineage_col].dropna().unique()
        colors_cmap = plt.get_cmap('tab20', len(unique_track_ids))
        track_colors = {track_id: colors_cmap(i) for i, track_id in enumerate(unique_track_ids)}

    for index, region_props in full_region_df.iterrows():
        # 'coords' are assumed to be (row, col) pixels within the mask
        cell_pixel_coords = np.array(region_props['coords']) # e.g., [[r1,c1], [r2,c2], ...]

        # Calculate bounding box for the current cell's mask
        min_row, min_col = np.min(cell_pixel_coords, axis=0)
        max_row, max_col = np.max(cell_pixel_coords, axis=0)

        # Create a small temporary mask for the current cell
        # Add a small buffer to ensure contours are fully captured if they go to edge
        buffer = 1
        bbox_min_row = max(0, min_row - buffer)
        bbox_min_col = max(0, min_col - buffer)
        bbox_max_row = min(kymograph_shape[0], max_row + buffer)
        bbox_max_col = min(kymograph_shape[1], max_col + buffer)

        temp_mask_shape = (bbox_max_row - bbox_min_row + 1, bbox_max_col - bbox_min_col + 1)
        temp_mask = np.zeros(temp_mask_shape, dtype=np.uint8)

        # Map cell_pixel_coords to relative coordinates within temp_mask
        relative_rows = cell_pixel_coords[:, 0] - bbox_min_row
        relative_cols = cell_pixel_coords[:, 1] - bbox_min_col
        
        # Populate the temporary mask
        temp_mask[relative_rows, relative_cols] = 1

        # Find contours on this small temporary mask
        # level=0.5 means it finds contours at the boundary between 0 and 1
        # fully_connected='high' means it considers 8-connectivity for background, 4-connectivity for foreground
        contours = find_contours(temp_mask, level=0.5, fully_connected='high')

        if not contours:
            continue # Skip if no contour found (e.g., single pixel or degenerate mask)

        # `find_contours` returns (row, col) coordinates for the contour.
        # We need to convert them back to global kymograph coordinates.
        # And convert to (x, y) for plotting (col, row)
        global_contours = []
        for contour in contours:
            # Shift back to global coordinates and swap for (x, y) plotting
            global_contour_x = contour[:, 1] + bbox_min_col
            global_contour_y = contour[:, 0] + bbox_min_row
            global_contours.append(np.vstack([global_contour_x, global_contour_y]).T)

        y_coord = region_props[y_coord_col]
        x_coord = region_props[x_coord_col]
        
        # Determine color for the current cell
        if lineage_col and region_props[lineage_col] in track_colors:
            current_color = track_colors[region_props[lineage_col]]
        else:
            current_color = default_cell_contour_color

        # Add all contours for this cell to the main list, with the determined color
        for contour_segment in global_contours:
            all_contours_segments.append(contour_segment)
            all_contour_colors.append(current_color)
            
        # Add centroid data
        centroid_x_coords.append(x_coord)
        centroid_y_coords.append(y_coord)
        centroid_colors.append(current_color if lineage_col else default_centroid_color)
        
        # --- Add Track ID Text ---
        if lineage_col and pd.notna(region_props[lineage_col]):
            track_id = region_props[lineage_col]
            # Convert track_id to int if it's a float, for cleaner display
            if isinstance(track_id, float) and track_id.is_integer():
                track_id_display = int(track_id)
            else:
                track_id_display = track_id

            all_text_params.append({
                'x': x_coord + text_offset_x,
                'y': y_coord + text_offset_y,
                's': str(track_id_display),
                'color': text_color,
                'fontsize': 8,
                'ha': 'left', # horizontal alignment
                'va': 'center', # vertical alignment
                'bbox': dict(facecolor=current_color, edgecolor='none', alpha=0.6, pad=1.0) # Background box
            })

    # Plot all cell contours at once using LineCollection
    if all_contours_segments: # Only plot if there are segments to draw
        line_collection = LineCollection(all_contours_segments, colors=all_contour_colors, linewidths=0.5)
        ax.add_collection(line_collection)

    # Plot all centroids at once using scatter
    if centroid_x_coords: # Only plot if there are centroids
        ax.scatter(centroid_x_coords, centroid_y_coords, color=centroid_colors, s=5, zorder=2)
    # Plot all track ID text at once
    for params in all_text_params:
        ax.text(params['x'], params['y'], params['s'], color=params['color'],
                fontsize=params['fontsize'], ha=params['ha'], va=params['va'],
                bbox=params['bbox'])

# %%
unique_fovs = df_for_kymograph_plot[['experiment_name', 'FOV', 'trench_id']].drop_duplicates().to_records(index=False)

# %%
for cell in unique_fovs:
    exp, fov, trench = cell
    # path_to_phase_kymograph = f'/Users/noravivancogonzalez/Documents/DuMM_image_analysis/{exp}/hyperstacked/drift_corrected/fast4deg_drift_corrected/rotated/mm_channels/subtracted/{fov}_{trench}.tif'
    # path_to_fluor_kymograph = f'/Users/noravivancogonzalez/Documents/DuMM_image_analysis/{exp}//hyperstacked/drift_corrected/fast4deg_drift_corrected/rotated/mm_channels/subtracted/fluor/{fov}_{trench}.tif'
    
    
    path_to_phase_kymograph = f'/Users/noravivancogonzalez/Documents/DuMM_image_analysis/{exp}/hyperstacked/drift_corrected/rotated/mm_channels/subtracted/{fov}_{trench}.tif'
    path_to_fluor_kymograph = f'/Users/noravivancogonzalez/Documents/DuMM_image_analysis/{exp}/hyperstacked/drift_corrected/rotated/mm_channels/subtracted/fluor/{fov}_{trench}.tif'
    
    # path_to_phase_kymograph = f'/Users/noravivancogonzalez/Documents/DuMM_image_analysis/{exp}/kymographs/phase/{fov}_{trench}.tif'
    # path_to_fluor_kymograph = f'/Users/noravivancogonzalez/Documents/DuMM_image_analysis/{exp}//kymographs/fluor/{fov}_{trench}.tif'
    
    if os.path.exists(path_to_phase_kymograph) and os.path.exists(path_to_fluor_kymograph):
        print(cell)
    
        phase_kymograph = tifffile.imread(path_to_phase_kymograph)
        fluor_kymograph = tifffile.imread(path_to_fluor_kymograph)
        df_view = df_for_kymograph_plot[df_for_kymograph_plot['experiment_name'].isin([exp]) &
                                  df_for_kymograph_plot['FOV'].isin([fov]) &
                                  df_for_kymograph_plot['trench_id'].isin([trench])].copy()
        plot_kymograph_cells_id(phase_kymograph, fluor_kymograph, 
                                    df_view, 
                                    exp, fov, trench, 
                                    track_id_col='track_id')
        plot_kymograph_cells_id(phase_kymograph, fluor_kymograph, 
                                    df_view, 
                                    exp, fov, trench, 
                                    track_id_col='predicted_lineage')
